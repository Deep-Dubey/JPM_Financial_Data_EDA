# %% [markdown]
# <a href="https://colab.research.google.com/github/Deep-Dubey/JPM_Financial_Data_EDA/blob/main/JPM_Financial_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jp = pd.read_csv('/content/jpm_financial_eda_rf.csv')
jp.head()
# Out:
#    customer_id  age       city account_type   balance  monthly_income  \
# 0         1000   59      Delhi      Current  269050.0         61670.0
# 1         1001   49       Pune      Savings  277058.0         49600.0
# 2         1002   35  Hyderabad      Savings  579344.0         52825.0
# 3         1003   63       Pune      Current  194156.0         58370.0
# 4         1004   28  Hyderabad      Savings  527495.0         56352.0
#
#    credit_score  transaction_amount merchant_category risk_bucket  \
# 0         479.0             22896.0            Travel      Medium
# 1         365.0             29792.0         Utilities         Low
# 2         647.0             29325.0            Travel      Medium
# 3         470.0             31051.0            Travel      Medium
# 4         773.0             28492.0          Shopping        High
#
#       transaction_date  default_flag
# 0  2024-01-01 00:00:00             1
# 1  2024-01-01 01:00:00             1
# ...

# %%
jp.shape
# Out:
# (1240, 12)

# %%
jp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         1240 non-null   int64
#  1   age                 1240 non-null   int64
#  2   city                1240 non-null   object
#  3   account_type        1240 non-null   object
#  4   balance             1178 non-null   float64
#  5   monthly_income      1178 non-null   float64
#  6   credit_score        1178 non-null   float64
#  7   transaction_amount  1240 non-null   float64
#  8   merchant_category   1240 non-null   object
#  9   risk_bucket         1240 non-null   object
#  10  transaction_date    1240 non-null   object
#  11  default_flag        1240 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 116.4+ KB

# %%
jp.describe()
# Out:
#        customer_id          age        balance  monthly_income  credit_score  \
# count  1240.000000  1240.000000    1178.000000     1178.000000   1178.000000
# mean   1598.100000    42.629839  498229.748727    60042.707131    571.427844
# std     346.735026    12.654759  146449.166094    19697.294908    158.794622
# min    1000.000000    21.000000  -20714.000000     2002.000000    300.000000
# 25%    1299.750000    31.000000  396742.000000    46845.500000    429.000000
# 50%    1594.500000    44.000000  500137.000000    59273.500000    569.000000
# 75%    1897.250000    53.000000  601531.250000    73646.750000    703.750000
# max    2199.000000    64.000000  959292.000000   115320.000000    849.000000
#
#        transaction_amount  default_flag
# count         1240.000000   1240.000000
# mean         24484.905645      0.120968
# std          12079.138402      0.326221
# min          -9794.000000      0.000000
# 25%          16446.750000      0.000000
# ...

# %%
jp.isnull().sum()
# Out:
# customer_id            0
# age                    0
# city                   0
# account_type           0
# balance               62
# monthly_income        62
# credit_score          62
# transaction_amount     0
# merchant_category      0
# risk_bucket            0
# transaction_date       0
# default_flag           0
# dtype: int64

# %%
jp.isnull().mean()*100
# Out:
# customer_id           0.0
# age                   0.0
# city                  0.0
# account_type          0.0
# balance               5.0
# monthly_income        5.0
# credit_score          5.0
# transaction_amount    0.0
# merchant_category     0.0
# risk_bucket           0.0
# transaction_date      0.0
# default_flag          0.0
# dtype: float64

# %%
jp[jp.duplicated()]
# Out:
#       customer_id  age       city account_type   balance  monthly_income  \
# 1200         1764   40      Delhi      Savings  555290.0         74878.0
# 1201         1528   50  Bangalore      Current  395209.0         48700.0
# 1202         1025   32  Hyderabad      Current  669104.0         49025.0
# 1203         1190   59       Pune      Savings  661276.0         74901.0
# 1204         1748   47      Delhi      Current  430989.0         80068.0
# 1205         1314   25       Pune      Savings  298383.0         85383.0
# 1206         1043   45     Mumbai      Savings  656885.0         33088.0
# 1207         1409   46       Pune      Savings  316668.0         49572.0
# 1208         1847   64     Mumbai      Current       NaN         63397.0
# 1209         2057   63      Delhi      Current  687718.0         56504.0
# 1210         1917   21  Bangalore      Current  560313.0         53468.0
# 1211         1556   62     Mumbai      Current  257695.0         66778.0
# ...

# %%
jp.duplicated().sum()
# Out:
# np.int64(40)

# %%
jp.duplicated().mean()*100
# Out:
# np.float64(3.225806451612903)

# %%
jp.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1235     True
# 1236     True
# 1237     True
# 1238     True
# 1239     True
# Length: 1240, dtype: bool

# %%
jp = jp.drop_duplicates(keep='first')
jp
# Out:
#       customer_id  age       city account_type   balance  monthly_income  \
# 0            1000   59      Delhi      Current  269050.0         61670.0
# 1            1001   49       Pune      Savings  277058.0         49600.0
# 2            1002   35  Hyderabad      Savings  579344.0         52825.0
# 3            1003   63       Pune      Current  194156.0         58370.0
# 4            1004   28  Hyderabad      Savings  527495.0         56352.0
# ...           ...  ...        ...          ...       ...             ...
# 1195         2195   34       Pune      Savings  551653.0         62113.0
# 1196         2196   51  Bangalore      Savings  443951.0         87893.0
# 1197         2197   38  Bangalore      Current  423909.0         39096.0
# 1198         2198   27  Hyderabad      Current  410915.0             NaN
# 1199         2199   30     Mumbai      Current  484067.0         56621.0
#
#       credit_score  transaction_amount merchant_category risk_bucket  \
# ...

# %%
jp[jp.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, city, account_type, balance, monthly_income, credit_score, transaction_amount, merchant_category, risk_bucket, transaction_date, default_flag]
# Index: []

# %%
jp.isnull().sum()
# Out:
# customer_id            0
# age                    0
# city                   0
# account_type           0
# balance               60
# monthly_income        60
# credit_score          60
# transaction_amount     0
# merchant_category      0
# risk_bucket            0
# transaction_date       0
# default_flag           0
# dtype: int64

# %%
jp.shape
# Out:
# (1200, 12)

# %%
jp['balance'] = jp['balance'].fillna(jp['balance'].mean())
jp['monthly_income'] = jp['monthly_income'].fillna(jp['monthly_income'].mean())
jp['credit_score'] = jp['credit_score'].fillna(jp['credit_score'].mean())

# %%
jp.isnull().sum()
# Out:
# customer_id           0
# age                   0
# city                  0
# account_type          0
# balance               0
# monthly_income        0
# credit_score          0
# transaction_amount    0
# merchant_category     0
# risk_bucket           0
# transaction_date      0
# default_flag          0
# dtype: int64

# %%
jp = jp.dropna()

# %%
jp.shape
# Out:
# (1200, 12)

# %%
jp.head()
# Out:
#    customer_id  age       city account_type   balance  monthly_income  \
# 0         1000   59      Delhi      Current  269050.0         61670.0
# 1         1001   49       Pune      Savings  277058.0         49600.0
# 2         1002   35  Hyderabad      Savings  579344.0         52825.0
# 3         1003   63       Pune      Current  194156.0         58370.0
# 4         1004   28  Hyderabad      Savings  527495.0         56352.0
#
#    credit_score  transaction_amount merchant_category risk_bucket  \
# 0         479.0             22896.0            Travel      Medium
# 1         365.0             29792.0         Utilities         Low
# 2         647.0             29325.0            Travel      Medium
# 3         470.0             31051.0            Travel      Medium
# 4         773.0             28492.0          Shopping        High
#
#       transaction_date  default_flag
# 0  2024-01-01 00:00:00             1
# 1  2024-01-01 01:00:00             1
# ...

# %%
jp['default_flag'].value_counts()
# Out:
# default_flag
# 0    1053
# 1     147
# Name: count, dtype: int64

# %%
jp['default_flag'].value_counts(normalize=True)*100
# Out:
# default_flag
# 0    87.75
# 1    12.25
# Name: proportion, dtype: float64

# %% [markdown]
# ##This code will give all numeric null values with mean/median in single code.
#
# jp.fillna(jp.median(numeric_only=True), inplace=True)

# %%
jp.head()
# Out:
#    customer_id  age       city account_type   balance  monthly_income  \
# 0         1000   59      Delhi      Current  269050.0         61670.0
# 1         1001   49       Pune      Savings  277058.0         49600.0
# 2         1002   35  Hyderabad      Savings  579344.0         52825.0
# 3         1003   63       Pune      Current  194156.0         58370.0
# 4         1004   28  Hyderabad      Savings  527495.0         56352.0
#
#    credit_score  transaction_amount merchant_category risk_bucket  \
# 0         479.0             22896.0            Travel      Medium
# 1         365.0             29792.0         Utilities         Low
# 2         647.0             29325.0            Travel      Medium
# 3         470.0             31051.0            Travel      Medium
# 4         773.0             28492.0          Shopping        High
#
#       transaction_date  default_flag
# 0  2024-01-01 00:00:00             1
# 1  2024-01-01 01:00:00             1
# ...

# %%
jp['transaction_date'] = pd.to_datetime(jp['transaction_date'])

# %%
jp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         1200 non-null   int64
#  1   age                 1200 non-null   int64
#  2   city                1200 non-null   object
#  3   account_type        1200 non-null   object
#  4   balance             1200 non-null   float64
#  5   monthly_income      1200 non-null   float64
#  6   credit_score        1200 non-null   float64
#  7   transaction_amount  1200 non-null   float64
#  8   merchant_category   1200 non-null   object
#  9   risk_bucket         1200 non-null   object
#  10  transaction_date    1200 non-null   datetime64[ns]
#  11  default_flag        1200 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(4)
# memory usage: 154.2+ KB

# %%
jp['year'] = jp['transaction_date'].dt.year
jp['month'] = jp['transaction_date'].dt.month
jp['day'] = jp['transaction_date'].dt.day
jp['weekday'] = jp['transaction_date'].dt.weekday
jp['is_weekend'] = jp['transaction_date'].dt.weekday>=5

# %%
jp.head()
# Out:
#    customer_id  age       city account_type   balance  monthly_income  \
# 0         1000   59      Delhi      Current  269050.0         61670.0
# 1         1001   49       Pune      Savings  277058.0         49600.0
# 2         1002   35  Hyderabad      Savings  579344.0         52825.0
# 3         1003   63       Pune      Current  194156.0         58370.0
# 4         1004   28  Hyderabad      Savings  527495.0         56352.0
#
#    credit_score  transaction_amount merchant_category risk_bucket  \
# 0         479.0             22896.0            Travel      Medium
# 1         365.0             29792.0         Utilities         Low
# 2         647.0             29325.0            Travel      Medium
# 3         470.0             31051.0            Travel      Medium
# 4         773.0             28492.0          Shopping        High
#
#      transaction_date  default_flag  year  month  day  weekday  is_weekend
# ...

# %%
#Top Risk Segments
grouped = jp.groupby(['city','account_type','merchant_category','risk_bucket'])['default_flag']\
.mean().sort_values(ascending=False).head(10)

grouped
# Out:
# city       account_type  merchant_category  risk_bucket
# Delhi      Savings       Utilities          High           0.375000
#            Current       Travel             Medium         0.312500
# Pune       Savings       Travel             Medium         0.277778
# Hyderabad  Current       Utilities          Low            0.272727
# Bangalore  Savings       Utilities          Medium         0.266667
# Mumbai     Savings       Utilities          Medium         0.260870
# Bangalore  Savings       Travel             Low            0.250000
# Hyderabad  Current       Shopping           Medium         0.250000
# Mumbai     Savings       Shopping           Low            0.250000
# Bangalore  Savings       Shopping           Low            0.235294
# Name: default_flag, dtype: float64

# %%
jp.groupby('city')['default_flag'].mean()*100
# Out:
# city
# Bangalore    12.809917
# Delhi        12.288136
# Hyderabad    13.023256
# Mumbai       10.236220
# Pune         13.043478
# Name: default_flag, dtype: float64

# %%
city_wise = jp.groupby('city')['default_flag'].mean() * 100
plt.figure(figsize=(10, 6))
sns.barplot(x=city_wise.index, y=city_wise.values, palette='viridis')
plt.title('Default Flag Percentage by City')
plt.xlabel('City')
plt.ylabel('Default Flag %')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-89554134.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_wise.index, y=city_wise.values, palette='viridis')

# %%
jp.groupby('account_type')['default_flag'].mean()*100
# Out:
# account_type
# Current    11.677632
# Savings    12.837838
# Name: default_flag, dtype: float64

# %%
account = jp.groupby('account_type')['default_flag'].mean()*100
plt.figure(figsize=(10,7))
sns.barplot(x=account.index,y=account.values)
plt.title('Default Flag Percentage by Account Type')
plt.xlabel('Account Type')
plt.ylabel('Default Flag %')
plt.tight_layout()
plt.show()

# %%
jp.groupby('merchant_category')['default_flag'].mean()*100
# Out:
# merchant_category
# Shopping     11.463415
# Travel       11.256545
# Utilities    13.970588
# Name: default_flag, dtype: float64

# %%
merchand = jp.groupby('merchant_category')['default_flag'].mean()*100
plt.figure(figsize=(10,7))
sns.barplot(x=merchand.index,y=merchand.values)
plt.title('Default Flag Percentage by Merchand Type')
plt.xlabel('Merchand Type')
plt.ylabel('Default Flag %')
plt.tight_layout()
plt.show()

# %%
jp.groupby('risk_bucket')['default_flag'].mean()*100
# Out:
# risk_bucket
# High      10.704961
# Low       12.098765
# Medium    13.834951
# Name: default_flag, dtype: float64

# %%
risk = jp.groupby('risk_bucket')['default_flag'].mean()*100
plt.figure(figsize=(10,7))
sns.barplot(x=risk.index,y=risk.values)
plt.title('Default Flag Percentage by Risk Type')
plt.xlabel('Risk Type')
plt.ylabel('Default Flag %')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(jp[['age', 'balance', 'monthly_income', 'credit_score', 'transaction_amount']])
plt.title("Transaction Amount Distribution")
plt.ylabel("Amount")
plt.show()

# %%
cols = ['balance','monthly_income','transaction_amount','credit_score']

for col in cols:
  Q1 = jp[col].quantile(0.25)
  Q3 = jp[col].quantile(0.75)

  IQR = Q3 - Q1

  lower_limit = Q1 - 1.5*IQR
  upper_limit = Q3 + 1.5*IQR

  jp = jp[(jp[col]>=lower_limit) & (jp[col]<=upper_limit)]

# %%
plt.figure(figsize=(10,7))
sns.boxplot(jp[['age', 'balance', 'monthly_income', 'credit_score', 'transaction_amount']])
plt.title("Transaction Amount Distribution")
plt.ylabel("Amount")
plt.show()

# %%
jp.head()
# Out:
#    customer_id  age       city account_type   balance  monthly_income  \
# 0         1000   59      Delhi      Current  269050.0         61670.0
# 1         1001   49       Pune      Savings  277058.0         49600.0
# 2         1002   35  Hyderabad      Savings  579344.0         52825.0
# 3         1003   63       Pune      Current  194156.0         58370.0
# 4         1004   28  Hyderabad      Savings  527495.0         56352.0
#
#    credit_score  transaction_amount merchant_category risk_bucket  \
# 0         479.0             22896.0            Travel      Medium
# 1         365.0             29792.0         Utilities         Low
# 2         647.0             29325.0            Travel      Medium
# 3         470.0             31051.0            Travel      Medium
# 4         773.0             28492.0          Shopping        High
#
#      transaction_date  default_flag  year  month  day  weekday  is_weekend
# ...

# %%
jp = pd.get_dummies(jp,columns=['city','account_type','merchant_category','risk_bucket'])
jp
# Out:
#       customer_id  age   balance  monthly_income  credit_score  \
# 0            1000   59  269050.0     61670.00000         479.0
# 1            1001   49  277058.0     49600.00000         365.0
# 2            1002   35  579344.0     52825.00000         647.0
# 3            1003   63  194156.0     58370.00000         470.0
# 4            1004   28  527495.0     56352.00000         773.0
# ...           ...  ...       ...             ...           ...
# 1195         2195   34  551653.0     62113.00000         501.0
# 1196         2196   51  443951.0     87893.00000         629.0
# 1197         2197   38  423909.0     39096.00000         662.0
# 1198         2198   27  410915.0     59977.89386         753.0
# 1199         2199   30  484067.0     56621.00000         655.0
#
#       transaction_amount    transaction_date  default_flag  year  month  ...  \
# 0                22896.0 2024-01-01 00:00:00             1  2024      1  ...
# ...

# %%
model = jp.select_dtypes(include='bool').columns
jp[model] = jp[model].astype(int)

# %%
jp.head()
# Out:
#    customer_id  age   balance  monthly_income  credit_score  \
# 0         1000   59  269050.0         61670.0         479.0
# 1         1001   49  277058.0         49600.0         365.0
# 2         1002   35  579344.0         52825.0         647.0
# 3         1003   63  194156.0         58370.0         470.0
# 4         1004   28  527495.0         56352.0         773.0
#
#    transaction_amount    transaction_date  default_flag  year  month  ...  \
# 0             22896.0 2024-01-01 00:00:00             1  2024      1  ...
# 1             29792.0 2024-01-01 01:00:00             1  2024      1  ...
# 2             29325.0 2024-01-01 02:00:00             0  2024      1  ...
# 3             31051.0 2024-01-01 03:00:00             0  2024      1  ...
# 4             28492.0 2024-01-01 04:00:00             0  2024      1  ...
#
#    city_Mumbai  city_Pune  account_type_Current  account_type_Savings  \
# 0            0          0                     1                     0
# ...

# %%
jp.head()
# Out:
#    customer_id  age   balance  monthly_income  credit_score  \
# 0         1000   59  269050.0         61670.0         479.0
# 1         1001   49  277058.0         49600.0         365.0
# 2         1002   35  579344.0         52825.0         647.0
# 3         1003   63  194156.0         58370.0         470.0
# 4         1004   28  527495.0         56352.0         773.0
#
#    transaction_amount    transaction_date  default_flag  year  month  ...  \
# 0             22896.0 2024-01-01 00:00:00             1  2024      1  ...
# 1             29792.0 2024-01-01 01:00:00             1  2024      1  ...
# 2             29325.0 2024-01-01 02:00:00             0  2024      1  ...
# 3             31051.0 2024-01-01 03:00:00             0  2024      1  ...
# 4             28492.0 2024-01-01 04:00:00             0  2024      1  ...
#
#    city_Mumbai  city_Pune  account_type_Current  account_type_Savings  \
# 0            0          0                     1                     0
# ...

# %%
jp = jp.drop('transaction_date',axis=1)
jp
# Out:
#       customer_id  age   balance  monthly_income  credit_score  \
# 0            1000   59  269050.0     61670.00000         479.0
# 1            1001   49  277058.0     49600.00000         365.0
# 2            1002   35  579344.0     52825.00000         647.0
# 3            1003   63  194156.0     58370.00000         470.0
# 4            1004   28  527495.0     56352.00000         773.0
# ...           ...  ...       ...             ...           ...
# 1195         2195   34  551653.0     62113.00000         501.0
# 1196         2196   51  443951.0     87893.00000         629.0
# 1197         2197   38  423909.0     39096.00000         662.0
# 1198         2198   27  410915.0     59977.89386         753.0
# 1199         2199   30  484067.0     56621.00000         655.0
#
#       transaction_amount  default_flag  year  month  day  ...  city_Mumbai  \
# 0                22896.0             1  2024      1    1  ...            0
# ...

# %%
jp.head()
# Out:
#    customer_id  age   balance  monthly_income  credit_score  \
# 0         1000   59  269050.0         61670.0         479.0
# 1         1001   49  277058.0         49600.0         365.0
# 2         1002   35  579344.0         52825.0         647.0
# 3         1003   63  194156.0         58370.0         470.0
# 4         1004   28  527495.0         56352.0         773.0
#
#    transaction_amount  default_flag  year  month  day  ...  city_Mumbai  \
# 0             22896.0             1  2024      1    1  ...            0
# 1             29792.0             1  2024      1    1  ...            0
# 2             29325.0             0  2024      1    1  ...            0
# 3             31051.0             0  2024      1    1  ...            0
# 4             28492.0             0  2024      1    1  ...            0
#
#    city_Pune  account_type_Current  account_type_Savings  \
# 0          0                     1                     0
# ...

# %%
jp.shape
# Out:
# (1170, 25)

# %% [markdown]
# #Random Forest

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.ensemble import RandomForestClassifier

# %%
flag = pd.get_dummies(jp,drop_first=True)
flag
# Out:
#       customer_id  age   balance  monthly_income  credit_score  \
# 0            1000   59  269050.0     61670.00000         479.0
# 1            1001   49  277058.0     49600.00000         365.0
# 2            1002   35  579344.0     52825.00000         647.0
# 3            1003   63  194156.0     58370.00000         470.0
# 4            1004   28  527495.0     56352.00000         773.0
# ...           ...  ...       ...             ...           ...
# 1195         2195   34  551653.0     62113.00000         501.0
# 1196         2196   51  443951.0     87893.00000         629.0
# 1197         2197   38  423909.0     39096.00000         662.0
# 1198         2198   27  410915.0     59977.89386         753.0
# 1199         2199   30  484067.0     56621.00000         655.0
#
#       transaction_amount  default_flag  year  month  day  ...  city_Mumbai  \
# 0                22896.0             1  2024      1    1  ...            0
# ...

# %%
X = jp.drop(['default_flag','transaction_amount'],axis=1)
y = jp['default_flag']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,stratify=y,random_state=42)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

print("Before SMOTE (Training data):")
print(y_train.value_counts())
print("\nAfter SMOTE (Resampled Training data):")
print(pd.Series(y_train_res).value_counts())
# Out:
# Before SMOTE (Training data):
# default_flag
# 0    768
# 1    109
# Name: count, dtype: int64
#
# After SMOTE (Resampled Training data):
# default_flag
# 0    768
# 1    768
# Name: count, dtype: int64

# %%
rf = RandomForestClassifier(n_estimators=100,class_weight='balanced', random_state=42)

# %%
cv_params = {
    'max_depth':[2,3,4,5,None],
    'min_samples_leaf':[1,2,3],
    'min_samples_split':[2,3,4],
    'max_features':[2,3,4],
    'n_estimators':[75,100,125,150]
    }

# %%
scoring = {"accuracy":"accuracy","precision":"precision","recall":"recall","f1":"f1"}

# %%
from sklearn.model_selection import RandomizedSearchCV
rf_cv = RandomizedSearchCV(
    rf,
    cv_params,
    n_iter=20,
    scoring=scoring,
    refit="f1",
    cv=3,
    n_jobs=-1,
    verbose=2
)

# %%
rf_cv.fit(X_train_res, y_train_res)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3,
#                    estimator=RandomForestClassifier(class_weight='balanced',
#                                                     random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'max_depth': [2, 3, 4, 5, None],
#                                         'max_features': [2, 3, 4],
#                                         'min_samples_leaf': [1, 2, 3],
#                                         'min_samples_split': [2, 3, 4],
#                                         'n_estimators': [75, 100, 125, 150]},
#                    refit='f1',
#                    scoring={'accuracy': 'accuracy', 'f1': 'f1',
#                             'precision': 'precision', 'recall': 'recall'},
#                    verbose=2)

# %%
y_pred = rf_cv.best_estimator_.predict(X_test)

# %%
#Probability
y_prob = rf_cv.best_estimator_.predict_proba(X_test)[:,1]
y_prob
# Out:
# array([0.18903238, 0.1418381 , 0.21802844, 0.30122406, 0.25064002,
#        0.17582637, 0.17363443, 0.21265399, 0.27927832, 0.25242265,
#        0.24419707, 0.20514025, 0.08846667, 0.48876816, 0.24136092,
#        0.23794892, 0.26941657, 0.16660952, 0.21735238, 0.35448566,
#        0.12533373, 0.19763777, 0.2204381 , 0.1714    , 0.29906566,
#        0.16622055, 0.28808386, 0.20356113, 0.20513753, 0.2162826 ,
#        0.19775873, 0.08575439, 0.1652    , 0.32878119, 0.20355325,
#        0.14445937, 0.23032103, 0.10315238, 0.41614771, 0.13862679,
#        0.34708571, 0.16248977, 0.13701587, 0.41871588, 0.24094036,
#        0.15884726, 0.29101212, 0.26428571, 0.09920952, 0.39044151,
#        0.22997354, 0.39409639, 0.23652271, 0.26499048, 0.15054237,
#        0.27295539, 0.15818216, 0.22974945, 0.31735909, 0.19399159,
#        0.10072036, 0.23061732, 0.07818398, 0.21908571, 0.21550476,
#        0.15153612, 0.21443779, 0.16401836, 0.23211775, 0.49084558,
# ...

# %%
rf_cv.best_score_
# Out:
# np.float64(0.9117326476487363)

# %%
rf_cv.best_params_
# Out:
# {'n_estimators': 125,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 3,
#  'max_depth': None}

# %%
print("Accuracy",accuracy_score(y_test,y_pred))
# Out:
# Accuracy 0.8737201365187713

# %%
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score,ConfusionMatrixDisplay

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       257
#            1       0.33      0.03      0.05        36
#
#     accuracy                           0.87       293
#    macro avg       0.61      0.51      0.49       293
# weighted avg       0.81      0.87      0.82       293

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=np.unique(y_test))
disp.plot()

# %%
print(f"ROC AUC Score: {roc_auc_score(y_test, y_prob)}")
# Out:
# ROC AUC Score: 0.47351923908344146

# %%
from sklearn.metrics import roc_curve, RocCurveDisplay

# Plot the ROC curve
fig, ax = plt.subplots(figsize=(10, 8))
roc_display = RocCurveDisplay(fpr=roc_curve(y_test, y_prob)[0],
                              tpr=roc_curve(y_test, y_prob)[1],
                              roc_auc=roc_auc_score(y_test, y_prob),
                              estimator_name='Random Forest Classifier')
roc_display.plot(ax=ax)
plt.title('ROC Curve for Random Forest Model (After Scaling)')
plt.plot([0, 1], [0, 1], 'k--', label='Random Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get feature importances from the best estimator
feature_importances = rf_cv.best_estimator_.feature_importances_

# Create a DataFrame for better visualization
features_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
})

# Sort the features by importance in descending order
features_df = features_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=features_df)
plt.title('Feature Importances from Random Forest Model')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What the Current Model Metrics Tell Us:
#
# *   **Accuracy:** The proportion of correctly classified instances. A high accuracy (like 1.0) means the model is performing very well on the test data.
# *   **Precision:** For class 1 (default), it's the proportion of actual defaults among those predicted as default. For class 0 (no default), it's the proportion of actual non-defaults among those predicted as non-default.
# *   **Recall:** For class 1 (default), it's the proportion of actual defaults that were correctly identified. For class 0, it's the proportion of actual non-defaults that were correctly identified.
# *   **F1-Score:** The harmonic mean of precision and recall. It's a good metric for imbalanced datasets like this one, where default cases are much fewer.
# *   **Confusion Matrix:** Shows the number of true positives, true negatives, false positives, and false negatives. In our case, `[[255, 2], [35, 1]]` indicates:
#     *   255 True Negatives (correctly predicted no default)
#     *   2 False Positives (incorrectly predicted default when it was no default)
#     *   35 False Negatives (incorrectly predicted no default when it was default)
#     *   1 True Positive (correctly predicted default)
# *   **ROC AUC Score:** Measures the model's ability to distinguish between classes across all possible classification thresholds. An AUC of 1.0 indicates a perfect classifier.
